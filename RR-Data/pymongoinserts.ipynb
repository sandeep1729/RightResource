# %%
from pymongo import MongoClient
import os
import gridfs
import docx

# %%
conn = MongoClient("mongodb://sandeep:382pFnNihl0L9HI9@cluster0-shard-00-00-2ivm7.mongodb.net:27017,cluster0-shard-00-01-2ivm7.mongodb.net:27017,cluster0-shard-00-02-2ivm7.mongodb.net:27017/test?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin")

# %%
db=conn['test']

# %%
conn.database_names() # getting database names
# Out:
# ['RightResource', 'mydb', 'test', 'admin', 'local']

# %%
db.collection_names()
# Out:
# ['movie', 'fs.chunks', 'mycollection', 'mon', 'fs.files', 'harish', 'test']

# %%
rrdb = conn['RightResource'] # getting the index

# %%
rrcol=rrdb['resources'] # getting the collection from the index

# %%
rrcol.insert_one({_id:1,name:"sandeep"})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-140-73e57e208f82> in <module>()
# ----> 1 rrcol.insert_one({_id:1,name:"sandeep"})
#
# NameError: name '_id' is not defined

# %%
rrcol.find("{_id:1}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-139-2412a89d00b6> in <module>()
# ----> 1 rrcol.find("{_id:1}")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymongo\collection.py in find(self, *args, **kwargs)
#    1237         .. mongodoc:: find
#    1238         """
# -> 1239         return Cursor(self, *args, **kwargs)
#    1240
#    1241     def parallel_scan(self, num_cursors, **kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymongo\cursor.py in __init__(self, collection, filter, projection, skip, limit, no_cursor_timeout, cursor_type, sort, allow_partial_results, oplog_replay, modifiers, batch_size, manipulate, collation)
#     121             spec = {}
#     122
# --> 123         validate_is_mapping("filter", spec)
#     124         if not isinstance(skip, int):
#     125             raise TypeError("skip must be an instance of int")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymongo\common.py in validate_is_mapping(option, value)
#     396         raise TypeError("%s must be an instance of dict, bson.son.SON, or "
#     397                         "other type that inherits from "
# --> 398                         "collections.Mapping" % (option,))
#     399
#     400
#
# TypeError: filter must be an instance of dict, bson.son.SON, or other type that inherits from collections.Mapping

# %%
fs = gridfs.GridFS(rrdb)

# %%
#a=fs.put(b"hello world")

# %%
doc = docx.Document('C:/Users/sandeep/work/sample.docx')

# %%
doc.save('C:/Users/sandeep/work/sampled.docx')

# %%
filename="C:/Users/sandeep/work/sampled.docx"
fileext=str(os.path.splitext(filename)[1]).lower()


filetype = ""
def formatswitcher(fileext):
    if(fileext == ".docx"):
        filetype="application/docx"
    elif(fileext is ".pdf"):
        filetype="application/pdf"
    elif(fileext is ".doc"):
        filetype="application/doc"
    elif(fileext is ".jpeg"):
        filetype="jpeg"
    elif(fileext is ".png"):
        filetype="png"
    else:
        filetype="invalid"
    return filetype
# Out:
# 'application/docx'

# %%
filebuffer = open(filename,"rb")

# %%
def insert(cid,filetype,filebuffer):
    if(fs.exists(_id=cid)==True):
        print("file already exist updating the document with latest information")
        fs.delete(cid)
        fs.put(filebuffer,_id=cid, ContentType=filetype)
    else:
        fs.put(filebuffer,_id=cid, ContentType=filetype)

# %%
def receive(cid,outpath):
    rawfile = open("C:/Users/sandeep/work/sampleds.docx",'wb')

# %%
insert(1,filetype,filebuffer)
# Out:
# file already exist updating the document with latest information

# %%
# Out:
# <bound method GridFS.get of <gridfs.GridFS object at 0x000001E231988AC8>>

# %%
x= fs.get(1)

# %%
print(x.read())
# Out:
# b'PK\x03\x04\x14\x00\x00\x00\x08\x00\
# %%
lst
# Out:
# [{'_id': ObjectId('58bc920ea488c214b8e5ea8d'),
#   'chunkSize': 261120,
#   'length': 11,
#   'md5': '5eb63bbbe01eeed093cb22bb8f5acdc3',
#   'uploadDate': datetime.datetime(2017, 3, 5, 22, 32, 47, 89000)},
#  {'_id': ObjectId('58bc9233a488c214b8e5ea8f'),
#   'chunkSize': 261120,
#   'length': 11,
#   'md5': '5eb63bbbe01eeed093cb22bb8f5acdc3',
#   'uploadDate': datetime.datetime(2017, 3, 5, 22, 33, 23, 977000)},
#  {'_id': ObjectId('58bc962ba488c214b8e5ea91'),
#   'chunkSize': 261120,
#   'length': 0,
#   'md5': 'd41d8cd98f00b204e9800998ecf8427e',
#   'uploadDate': datetime.datetime(2017, 3, 5, 22, 50, 19, 766000)},
#  {'_id': ObjectId('58bc96e6a488c214b8e5ea92'),
#   'chunkSize': 261120,
#   'length': 0,
#   'md5': 'd41d8cd98f00b204e9800998ecf8427e',
#   'uploadDate': datetime.datetime(2017, 3, 5, 22, 53, 26, 798000)},
#  {'_id': ObjectId('58bc99e4a488c214b8e5ea93'),
#   'chunkSize': 261120,
#   'length': 26950,
#   'md5': '8f6c970999910355fb8639f7f61ca3c6',
#   'uploadDate': datetime.datetime(2017, 3, 5, 23, 6, 12, 227000)},
#  {'_id': ObjectId('58bc9ba6a488c214b8e5ea95'),
#   'chunkSize': 261120,
#   'length': 26950,
#   'md5': '8f6c970999910355fb8639f7f61ca3c6',
#   'uploadDate': datetime.datetime(2017, 3, 5, 23, 13, 43, 10000)},
#  {'_id': ObjectId('58bc9bdda488c214b8e5ea97'),
#   'chunkSize': 261120,
#   'length': 26950,
#   'md5': '8f6c970999910355fb8639f7f61ca3c6',
#   'uploadDate': datetime.datetime(2017, 3, 5, 23, 14, 37, 167000)},
#  {'_id': ObjectId('58bc9e5aa488c214b8e5ea99'),
#   'chunkSize': 261120,
#   'length': 26950,
#   'md5': '8f6c970999910355fb8639f7f61ca3c6',
#   'uploadDate': datetime.datetime(2017, 3, 5, 23, 25, 14, 107000)},
#  {'_id': ObjectId('58bc9f77a488c214b8e5ea9b'),
#   'chunkSize': 261120,
#   'length': 26950,
#   'md5': '8f6c970999910355fb8639f7f61ca3c6',
#   'uploadDate': datetime.datetime(2017, 3, 5, 23, 29, 59, 408000)},
#  {'_id': ObjectId('58bc9fa6a488c214b8e5ea9d'),
#   'chunkSize': 261120,
#   'filename': 'resume',
#   'length': 0,
#   'md5': 'd41d8cd98f00b204e9800998ecf8427e',
#   'uploadDate': datetime.datetime(2017, 3, 5, 23, 30, 46, 224000)},
#  {'_id': ObjectId('58bca50ea488c214b8e5ea9e'),
#   'chunkSize': 261120,
#   'filename': 'resume',
#   'length': 26950,
#   'md5': '8f6c970999910355fb8639f7f61ca3c6',
#   'uploadDate': datetime.datetime(2017, 3, 5, 23, 53, 51, 263000)},
#  {'_id': ObjectId('58bca550a488c214b8e5eaa0'),
#   'chunkSize': 261120,
#   'filename': 'resume',
#   'length': 26950,
#   'md5': '8f6c970999910355fb8639f7f61ca3c6',
#   'uploadDate': datetime.datetime(2017, 3, 5, 23, 54, 57, 304000)},
#  {'_id': ObjectId('58bca570a488c214b8e5eaa2'),
#   'chunkSize': 261120,
#   'filename': 'resume',
#   'length': 26950,
#   'md5': '8f6c970999910355fb8639f7f61ca3c6',
#   'uploadDate': datetime.datetime(2017, 3, 5, 23, 55, 28, 955000)},
#  {'_id': ObjectId('58bcb012a488c214b8e5eaa5'),
#   'chunkSize': 261120,
#   'length': 464,
#   'md5': 'a626bd45636857e186ab1daab730cde6',
#   'uploadDate': datetime.datetime(2017, 3, 6, 0, 40, 50, 875000)},
#  {'_id': ObjectId('58bcb082a488c214b8e5eaa7'),
#   'chunkSize': 261120,
#   'length': 267770,
#   'md5': 'eba5c9225d3ac784de28b2dac5c4a12d',
#   'uploadDate': datetime.datetime(2017, 3, 6, 0, 42, 43, 576000)},
#  {'ContentType': 'image/png',
#   '_id': ObjectId('58bcb145a488c214b8e5eaaa'),
#   'chunkSize': 261120,
#   'length': 267770,
#   'md5': 'eba5c9225d3ac784de28b2dac5c4a12d',
#   'uploadDate': datetime.datetime(2017, 3, 6, 0, 45, 58, 266000)},
#  {'_id': ObjectId('58bcb158a488c214b8e5eaad'),
#   'chunkSize': 261120,
#   'length': 267770,
#   'md5': 'eba5c9225d3ac784de28b2dac5c4a12d',
#   'uploadDate': datetime.datetime(2017, 3, 6, 0, 46, 17, 401000)},
#  {'_id': ObjectId('58bcb16ca488c214b8e5eab0'),
#   'chunkSize': 261120,
#   'length': 267770,
#   'md5': 'eba5c9225d3ac784de28b2dac5c4a12d',
#   'uploadDate': datetime.datetime(2017, 3, 6, 0, 46, 37, 959000)},
#  {'_id': ObjectId('58bcb1aba488c214b8e5eab3'),
#   'chunkSize': 261120,
#   'length': 30210,
#   'md5': '88b500dcabd7567b92cef84ad524f98a',
#   'uploadDate': datetime.datetime(2017, 3, 6, 0, 47, 39, 293000)},
#  {'_id': ObjectId('58bcb1e2a488c214b8e5eab5'),
#   'chunkSize': 261120,
#   'contentType': 'aplication/docx',
#   'length': 30210,
#   'md5': '88b500dcabd7567b92cef84ad524f98a',
#   'uploadDate': datetime.datetime(2017, 3, 6, 0, 48, 34, 889000)},
#  {'_id': ObjectId('58bcb1eaa488c214b8e5eab7'),
#   'chunkSize': 261120,
#   'contentType': 'aplication/docx',
#   'length': 30210,
#   'md5': '88b500dcabd7567b92cef84ad524f98a',
#   'uploadDate': datetime.datetime(2017, 3, 6, 0, 48, 42, 175000)},
#  {'_id': ObjectId('58bcb1f2a488c214b8e5eab9'),
#   'chunkSize': 261120,
#   'contentType': 'aplication/pdf',
#   'length': 30210,
#   'md5': '88b500dcabd7567b92cef84ad524f98a',
#   'uploadDate': datetime.datetime(2017, 3, 6, 0, 48, 50, 580000)},
#  {'ContentType': 'aplication/docx',
#   '_id': ObjectId('58bcb201a488c214b8e5eabb'),
#   'chunkSize': 261120,
#   'length': 30210,
#   'md5': '88b500dcabd7567b92cef84ad524f98a',
#   'uploadDate': datetime.datetime(2017, 3, 6, 0, 49, 5, 945000)}]

# %%
y
# Out:
# 1

# %%
fs.files.find(_id=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-bd361f4cccc8> in <module>()
# ----> 1 fs.files.find(_id=1)
#
# AttributeError: 'GridFS' object has no attribute 'files'
